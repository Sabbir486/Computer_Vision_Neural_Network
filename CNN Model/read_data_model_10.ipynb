# %%
import pickle
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import random
from tqdm import tqdm
import cv2
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
p = open(r'G:\Jupyter\Last Train 10\Pickel Files\train_imgs_10.pickle', 'rb')
train_imgs = pickle.load(p)
p.close()
p1 = open(r'G:\Jupyter\Last Train 10\Pickel Files\train_labels_10.pickle', 'rb')
train_labels = pickle.load(p1)
p1.close()

# %%
print(train_imgs.shape)
# Out:
# (370, 256, 256, 3)

# %%
train_imgs_np= train_imgs/ 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(256,256,3)),
    tf.keras.layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 256, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 256, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 512, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 512, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units = 256, activation='relu'),
    tf.keras.layers.Dense(units = 256, activation='relu'),
    tf.keras.layers.Dense(units = 64, activation='relu'),
    tf.keras.layers.Dropout(0.45),
    tf.keras.layers.Dense(units = 37, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 128)     73856
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 256)       819456
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 256)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 512)       3277312
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 512)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 512)         6554112
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 37)                2405
#
# =================================================================
# Total params: 14,547,237
# Trainable params: 14,547,237
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
h = model.fit(
    x=train_imgs,
    y=train_labels,
    epochs=100,  # Adjust the number of epochs as needed
    validation_split=0.4,  # Set a suitable validation split
    batch_size=20,  # Adjust the batch size as needed
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)],  # Early stopping to prevent overfitting
    verbose=1
)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 7s 147ms/step - loss: 5.5586 - accuracy: 0.0315 - val_loss: 3.7856 - val_accuracy: 0.0338
# Epoch 2/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.7572 - accuracy: 0.0405 - val_loss: 3.6594 - val_accuracy: 0.0068
# Epoch 3/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.6158 - accuracy: 0.0405 - val_loss: 3.6692 - val_accuracy: 0.0270
# Epoch 4/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.5530 - accuracy: 0.0856 - val_loss: 3.6173 - val_accuracy: 0.0541
# Epoch 5/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.5514 - accuracy: 0.0495 - val_loss: 3.6165 - val_accuracy: 0.0405
# Epoch 6/100
# 12/12 [==============================] - 1s 67ms/step - loss: 3.5389 - accuracy: 0.0901 - val_loss: 3.6437 - val_accuracy: 0.0270
# Epoch 7/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.5673 - accuracy: 0.0450 - val_loss: 3.6288 - val_accuracy: 0.0270
# Epoch 8/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.5136 - accuracy: 0.0586 - val_loss: 3.6062 - val_accuracy: 0.0473
# Epoch 9/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.4387 - accuracy: 0.0946 - val_loss: 3.5844 - val_accuracy: 0.1014
# Epoch 10/100
# 12/12 [==============================] - 1s 70ms/step - loss: 3.3857 - accuracy: 0.0901 - val_loss: 3.6069 - val_accuracy: 0.0541
# Epoch 11/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.3957 - accuracy: 0.0946 - val_loss: 3.5762 - val_accuracy: 0.0676
# Epoch 12/100
# 12/12 [==============================] - 1s 68ms/step - loss: 3.4521 - accuracy: 0.0856 - val_loss: 3.6139 - val_accuracy: 0.0743
# Epoch 13/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.4645 - accuracy: 0.0991 - val_loss: 3.5940 - val_accuracy: 0.0676
# Epoch 14/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.3801 - accuracy: 0.1351 - val_loss: 3.6062 - val_accuracy: 0.0676
# Epoch 15/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.3271 - accuracy: 0.1261 - val_loss: 3.5674 - val_accuracy: 0.0473
# Epoch 16/100
# 12/12 [==============================] - 1s 70ms/step - loss: 3.3373 - accuracy: 0.0946 - val_loss: 3.6472 - val_accuracy: 0.0473
# Epoch 17/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.3154 - accuracy: 0.1261 - val_loss: 3.5822 - val_accuracy: 0.0676
# Epoch 18/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.3085 - accuracy: 0.1577 - val_loss: 3.5668 - val_accuracy: 0.0743
# Epoch 19/100
# 12/12 [==============================] - 1s 65ms/step - loss: 3.1807 - accuracy: 0.1712 - val_loss: 3.5276 - val_accuracy: 0.0878
# Epoch 20/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.1253 - accuracy: 0.1577 - val_loss: 3.5335 - val_accuracy: 0.0608
# Epoch 21/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.1697 - accuracy: 0.1847 - val_loss: 3.6141 - val_accuracy: 0.0811
# Epoch 22/100
# 12/12 [==============================] - 1s 66ms/step - loss: 3.1855 - accuracy: 0.1216 - val_loss: 3.5642 - val_accuracy: 0.0811
# Epoch 23/100
# 12/12 [==============================] - 1s 67ms/step - loss: 3.0924 - accuracy: 0.1532 - val_loss: 3.5693 - val_accuracy: 0.1149
# Epoch 24/100
# 12/12 [==============================] - 1s 68ms/step - loss: 3.0393 - accuracy: 0.1847 - val_loss: 3.5460 - val_accuracy: 0.1216

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')
plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')
plt.show()

# %%
model.save("face_recog_10.h5")
