# %%
import pickle
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import random
from tqdm import tqdm
import cv2
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
p = open(r'G:\Jupyter\Last Train 500\Pickel Files\train_imgs_500.pickle', 'rb')
train_imgs = pickle.load(p)
p.close()
p1 = open(r'G:\Jupyter\Last Train 500\Pickel Files\train_labels_500.pickle', 'rb')
train_labels = pickle.load(p1)
p1.close()

# %%
print(train_imgs.shape)
# Out:
# (18500, 256, 256, 3)

# %%
#train_imgs_np= train_imgs/ 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(256,256,3)),
    tf.keras.layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 256, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 256, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 512, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 512, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units = 256, activation='relu'),
    tf.keras.layers.Dense(units = 256, activation='relu'),
    tf.keras.layers.Dense(units = 64, activation='relu'),
    tf.keras.layers.Dropout(0.45),
    tf.keras.layers.Dense(units = 37, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 128)     73856
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 256)       819456
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 256)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 512)       3277312
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 512)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 512)         6554112
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 37)                2405
#
# =================================================================
# Total params: 14,547,237
# Trainable params: 14,547,237
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
h = model.fit(
    x=train_imgs,
    y=train_labels,
    epochs=100,  # Adjust the number of epochs as needed
    validation_split=0.5,  # Set a suitable validation split
    batch_size=316,  # Adjust the batch size as needed
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)],  # Early stopping to prevent overfitting
    verbose=1
)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 87s 2s/step - loss: 3.9720 - accuracy: 0.0280 - val_loss: 3.5771 - val_accuracy: 0.0350
# Epoch 2/100
# 30/30 [==============================] - 35s 1s/step - loss: 3.5451 - accuracy: 0.0501 - val_loss: 3.4729 - val_accuracy: 0.0824
# Epoch 3/100
# 30/30 [==============================] - 36s 1s/step - loss: 3.4760 - accuracy: 0.0650 - val_loss: 3.3655 - val_accuracy: 0.1036
# Epoch 4/100
# 30/30 [==============================] - 33s 1s/step - loss: 3.3916 - accuracy: 0.0870 - val_loss: 3.2791 - val_accuracy: 0.1228
# Epoch 5/100
# 30/30 [==============================] - 34s 1s/step - loss: 3.2882 - accuracy: 0.1137 - val_loss: 3.1466 - val_accuracy: 0.1674
# Epoch 6/100
# 30/30 [==============================] - 34s 1s/step - loss: 3.1791 - accuracy: 0.1421 - val_loss: 3.0087 - val_accuracy: 0.2006
# Epoch 7/100
# 30/30 [==============================] - 35s 1s/step - loss: 3.0354 - accuracy: 0.1761 - val_loss: 2.8460 - val_accuracy: 0.2526
# Epoch 8/100
# 30/30 [==============================] - 33s 1s/step - loss: 2.8996 - accuracy: 0.2028 - val_loss: 2.7157 - val_accuracy: 0.2838
# Epoch 9/100
# 30/30 [==============================] - 33s 1s/step - loss: 2.6971 - accuracy: 0.2551 - val_loss: 2.3784 - val_accuracy: 0.3799
# Epoch 10/100
# 30/30 [==============================] - 34s 1s/step - loss: 2.4975 - accuracy: 0.3085 - val_loss: 2.1579 - val_accuracy: 0.4524
# Epoch 11/100
# 30/30 [==============================] - 34s 1s/step - loss: 2.3262 - accuracy: 0.3542 - val_loss: 1.9763 - val_accuracy: 0.5022
# Epoch 12/100
# 30/30 [==============================] - 32s 1s/step - loss: 2.1240 - accuracy: 0.3988 - val_loss: 1.8533 - val_accuracy: 0.5383
# Epoch 13/100
# 30/30 [==============================] - 32s 1s/step - loss: 1.9940 - accuracy: 0.4424 - val_loss: 1.6292 - val_accuracy: 0.5879
# Epoch 14/100
# 30/30 [==============================] - 32s 1s/step - loss: 1.7579 - accuracy: 0.4981 - val_loss: 1.5418 - val_accuracy: 0.6035
# Epoch 15/100
# 30/30 [==============================] - 32s 1s/step - loss: 1.5988 - accuracy: 0.5387 - val_loss: 1.3660 - val_accuracy: 0.6423
# Epoch 16/100
# 30/30 [==============================] - 32s 1s/step - loss: 1.4133 - accuracy: 0.5861 - val_loss: 1.1889 - val_accuracy: 0.6924
# Epoch 17/100
# 30/30 [==============================] - 33s 1s/step - loss: 1.2688 - accuracy: 0.6195 - val_loss: 1.0836 - val_accuracy: 0.7291
# Epoch 18/100
# 30/30 [==============================] - 32s 1s/step - loss: 1.1636 - accuracy: 0.6506 - val_loss: 1.0121 - val_accuracy: 0.7419
# Epoch 19/100
# 30/30 [==============================] - 32s 1s/step - loss: 1.0491 - accuracy: 0.6870 - val_loss: 0.9145 - val_accuracy: 0.7666
# Epoch 20/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.9552 - accuracy: 0.7094 - val_loss: 0.9125 - val_accuracy: 0.7643
# Epoch 21/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.8243 - accuracy: 0.7427 - val_loss: 0.7882 - val_accuracy: 0.7950
# Epoch 22/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.7505 - accuracy: 0.7680 - val_loss: 0.7165 - val_accuracy: 0.8128
# Epoch 23/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.7100 - accuracy: 0.7811 - val_loss: 0.6533 - val_accuracy: 0.8301
# Epoch 24/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.6275 - accuracy: 0.8002 - val_loss: 0.6223 - val_accuracy: 0.8379
# Epoch 25/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.5866 - accuracy: 0.8138 - val_loss: 0.6962 - val_accuracy: 0.8256
# Epoch 26/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.5367 - accuracy: 0.8296 - val_loss: 0.6164 - val_accuracy: 0.8439
# Epoch 27/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.5241 - accuracy: 0.8359 - val_loss: 0.5735 - val_accuracy: 0.8564
# Epoch 28/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.4564 - accuracy: 0.8554 - val_loss: 0.6317 - val_accuracy: 0.8442
# Epoch 29/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.4548 - accuracy: 0.8535 - val_loss: 0.6291 - val_accuracy: 0.8391
# Epoch 30/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.4036 - accuracy: 0.8668 - val_loss: 0.4972 - val_accuracy: 0.8789
# Epoch 31/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.3872 - accuracy: 0.8758 - val_loss: 0.5205 - val_accuracy: 0.8773
# Epoch 32/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.3933 - accuracy: 0.8744 - val_loss: 0.4870 - val_accuracy: 0.8812
# Epoch 33/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.3414 - accuracy: 0.8853 - val_loss: 0.4884 - val_accuracy: 0.8804
# Epoch 34/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.3279 - accuracy: 0.8929 - val_loss: 0.4719 - val_accuracy: 0.8866
# Epoch 35/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2847 - accuracy: 0.9066 - val_loss: 0.4929 - val_accuracy: 0.8830
# Epoch 36/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2818 - accuracy: 0.9097 - val_loss: 0.5122 - val_accuracy: 0.8829
# Epoch 37/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2850 - accuracy: 0.9049 - val_loss: 0.4915 - val_accuracy: 0.8871
# Epoch 38/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2573 - accuracy: 0.9170 - val_loss: 0.4780 - val_accuracy: 0.8880
# Epoch 39/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2366 - accuracy: 0.9248 - val_loss: 0.4552 - val_accuracy: 0.8896
# Epoch 40/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2325 - accuracy: 0.9210 - val_loss: 0.4537 - val_accuracy: 0.8952
# Epoch 41/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2281 - accuracy: 0.9253 - val_loss: 0.4579 - val_accuracy: 0.8950
# Epoch 42/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2134 - accuracy: 0.9266 - val_loss: 0.4387 - val_accuracy: 0.8975
# Epoch 43/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.2090 - accuracy: 0.9319 - val_loss: 0.5024 - val_accuracy: 0.8919
# Epoch 44/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.1864 - accuracy: 0.9395 - val_loss: 0.4370 - val_accuracy: 0.9049
# Epoch 45/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.2063 - accuracy: 0.9349 - val_loss: 0.4536 - val_accuracy: 0.8963
# Epoch 46/100
# 30/30 [==============================] - 32s 1s/step - loss: 0.1756 - accuracy: 0.9430 - val_loss: 0.4321 - val_accuracy: 0.9055
# Epoch 47/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.1827 - accuracy: 0.9375 - val_loss: 0.4720 - val_accuracy: 0.8952
# Epoch 48/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.1735 - accuracy: 0.9443 - val_loss: 0.5129 - val_accuracy: 0.8921
# Epoch 49/100
# 30/30 [==============================] - 34s 1s/step - loss: 0.1753 - accuracy: 0.9430 - val_loss: 0.5354 - val_accuracy: 0.8883
# Epoch 50/100
# 30/30 [==============================] - 34s 1s/step - loss: 0.1574 - accuracy: 0.9458 - val_loss: 0.4136 - val_accuracy: 0.9096
# Epoch 51/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.1545 - accuracy: 0.9495 - val_loss: 0.4604 - val_accuracy: 0.8984
# Epoch 52/100
# 30/30 [==============================] - 34s 1s/step - loss: 0.1550 - accuracy: 0.9496 - val_loss: 0.4203 - val_accuracy: 0.9085
# Epoch 53/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.1617 - accuracy: 0.9453 - val_loss: 0.5071 - val_accuracy: 0.8904
# Epoch 54/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.1560 - accuracy: 0.9481 - val_loss: 0.4326 - val_accuracy: 0.9119
# Epoch 55/100
# 30/30 [==============================] - 33s 1s/step - loss: 0.1358 - accuracy: 0.9566 - val_loss: 0.4289 - val_accuracy: 0.9083

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')
plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')
plt.show()

# %%
model.save("face_recog_500.h5")
