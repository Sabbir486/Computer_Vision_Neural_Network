# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import random
from tqdm import tqdm
import cv2
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import pickle
import numpy as np

# %%
p = open('/content/drive/MyDrive/Tensorflow/train_imgs.pickle', 'rb')
train_imgs_np = pickle.load(p)

# %%
p2 = open('/content/drive/MyDrive/Tensorflow/train_labels.pickle', 'rb')
train_labels_np = pickle.load(p2)

# %%
print(train_imgs_np.shape, train_labels_np.shape)
# Out:
# (18500, 256, 256, 3) (18500,)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(256,256,3)),
    tf.keras.layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 128, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 256, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 512, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters = 512, kernel_size=(5,5), padding="same", activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units = 256, activation='relu'),
    tf.keras.layers.Dense(units = 256, activation='relu'),
    tf.keras.layers.Dense(units = 64, activation='relu'),
    tf.keras.layers.Dropout(0.45),
    tf.keras.layers.Dense(units = 37, activation='softmax')

])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 128)     204928
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 128)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 256)       819456
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 256)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 512)       3277312
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 512)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 512)       6554112
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 256)               8388864
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 37)                2405
#
# =================================================================
# Total params: 19331109 (73.74 MB)
# Trainable params: 19331109 (73.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
h = model.fit(
    x=train_imgs_np,
    y=train_labels_np,
    epochs=30,  # Adjust the number of epochs as needed
    validation_split=0.25,  # Set a suitable validation split
    batch_size=150,  # Adjust the batch size as needed
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)],  # Early stopping to prevent overfitting
    verbose=1
)
# Out:
# Epoch 1/30
# 93/93 [==============================] - 290s 2s/step - loss: 3.7842 - accuracy: 0.0271 - val_loss: 3.6038 - val_accuracy: 0.0298
# Epoch 2/30
# 93/93 [==============================] - 153s 2s/step - loss: 3.5970 - accuracy: 0.0333 - val_loss: 3.5821 - val_accuracy: 0.0376
# Epoch 3/30
# 93/93 [==============================] - 151s 2s/step - loss: 3.5772 - accuracy: 0.0377 - val_loss: 3.5570 - val_accuracy: 0.0398
# Epoch 4/30
# 93/93 [==============================] - 151s 2s/step - loss: 3.5449 - accuracy: 0.0435 - val_loss: 3.4787 - val_accuracy: 0.0696
# Epoch 5/30
# 93/93 [==============================] - 152s 2s/step - loss: 3.4976 - accuracy: 0.0566 - val_loss: 3.4476 - val_accuracy: 0.0863
# Epoch 6/30
# 93/93 [==============================] - 154s 2s/step - loss: 3.4385 - accuracy: 0.0734 - val_loss: 3.3487 - val_accuracy: 0.1181
# Epoch 7/30
# 93/93 [==============================] - 154s 2s/step - loss: 3.3553 - accuracy: 0.0958 - val_loss: 3.2903 - val_accuracy: 0.1442
# Epoch 8/30
# 93/93 [==============================] - 153s 2s/step - loss: 3.2710 - accuracy: 0.1159 - val_loss: 3.1529 - val_accuracy: 0.1782
# Epoch 9/30
# 93/93 [==============================] - 153s 2s/step - loss: 3.1872 - accuracy: 0.1320 - val_loss: 3.0854 - val_accuracy: 0.1935
# Epoch 10/30
# 93/93 [==============================] - 155s 2s/step - loss: 3.0794 - accuracy: 0.1622 - val_loss: 2.9541 - val_accuracy: 0.2311
# Epoch 11/30
# 93/93 [==============================] - 155s 2s/step - loss: 2.9884 - accuracy: 0.1782 - val_loss: 2.8402 - val_accuracy: 0.2551
# Epoch 12/30
# 93/93 [==============================] - 153s 2s/step - loss: 2.8847 - accuracy: 0.2053 - val_loss: 2.8026 - val_accuracy: 0.2735
# Epoch 13/30
# 93/93 [==============================] - 155s 2s/step - loss: 2.7763 - accuracy: 0.2275 - val_loss: 2.6651 - val_accuracy: 0.3010
# Epoch 14/30
# 93/93 [==============================] - 155s 2s/step - loss: 2.6815 - accuracy: 0.2472 - val_loss: 2.5751 - val_accuracy: 0.3321
# Epoch 15/30
# 93/93 [==============================] - 155s 2s/step - loss: 2.5711 - accuracy: 0.2740 - val_loss: 2.4443 - val_accuracy: 0.3697
# Epoch 16/30
# 93/93 [==============================] - 155s 2s/step - loss: 2.4717 - accuracy: 0.2920 - val_loss: 2.3410 - val_accuracy: 0.3797
# Epoch 17/30
# 93/93 [==============================] - 154s 2s/step - loss: 2.3791 - accuracy: 0.3165 - val_loss: 2.2555 - val_accuracy: 0.4186
# Epoch 18/30
# 93/93 [==============================] - 156s 2s/step - loss: 2.2645 - accuracy: 0.3472 - val_loss: 2.1367 - val_accuracy: 0.4519
# Epoch 19/30
# 93/93 [==============================] - 155s 2s/step - loss: 2.1580 - accuracy: 0.3754 - val_loss: 2.0273 - val_accuracy: 0.4882
# Epoch 20/30
# 93/93 [==============================] - 156s 2s/step - loss: 2.0669 - accuracy: 0.3962 - val_loss: 1.9276 - val_accuracy: 0.5014
# Epoch 21/30
# 93/93 [==============================] - 155s 2s/step - loss: 1.9858 - accuracy: 0.4133 - val_loss: 1.8313 - val_accuracy: 0.5410
# Epoch 22/30
# 93/93 [==============================] - 154s 2s/step - loss: 1.8789 - accuracy: 0.4441 - val_loss: 1.7450 - val_accuracy: 0.5639
# Epoch 23/30
# 93/93 [==============================] - 156s 2s/step - loss: 1.7916 - accuracy: 0.4723 - val_loss: 1.6805 - val_accuracy: 0.5797
# Epoch 24/30
# 93/93 [==============================] - 156s 2s/step - loss: 1.6945 - accuracy: 0.4911 - val_loss: 1.5919 - val_accuracy: 0.6041
# Epoch 25/30
# 93/93 [==============================] - 154s 2s/step - loss: 1.6443 - accuracy: 0.5098 - val_loss: 1.6391 - val_accuracy: 0.5890
# Epoch 26/30
# 93/93 [==============================] - 156s 2s/step - loss: 1.5347 - accuracy: 0.5394 - val_loss: 1.5331 - val_accuracy: 0.6082
# Epoch 27/30
# 93/93 [==============================] - 154s 2s/step - loss: 1.4863 - accuracy: 0.5504 - val_loss: 1.4520 - val_accuracy: 0.6333
# Epoch 28/30
# 93/93 [==============================] - 156s 2s/step - loss: 1.4236 - accuracy: 0.5673 - val_loss: 1.3754 - val_accuracy: 0.6508
# Epoch 29/30
# 93/93 [==============================] - 156s 2s/step - loss: 1.3338 - accuracy: 0.5881 - val_loss: 1.3301 - val_accuracy: 0.6592
# Epoch 30/30
# 93/93 [==============================] - 156s 2s/step - loss: 1.2895 - accuracy: 0.6027 - val_loss: 1.2962 - val_accuracy: 0.6802

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

model.save('18500dataModel.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.save('18500dataModel.h5')
